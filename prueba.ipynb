# %%
nombre = 'Alejandro'
edad = 19
ciudad = 'San Lorenzo'

print(nombre, edad, ciudad)
# Out:
# Alejandro 19 San Lorenzo

# %%
print('hola mundo)
# Out:
# hola mundo

# %%
Cantidad_de_manzanas= 10

Cantidad_de_naranjas= 20

Cantidad_de_frutas= Cantidad_de_manzanas+Cantidad_de_naranjas

print(Cantidad_de_frutas)
# Out:
# 30

# %%
frutas_vendidas= 50

cantidad_de_frutas1= 120

Ventas=cantidad_de_frutas1-frutas_vendidas

print('frutas_vendidas:', Ventas)
# Out:
# frutas_vendidas: 70

# %%
nombre= 'Omar'

apellido='alcatraz'

print(f'El nombre de mi compa es: {nombre} {apellido}')
# Out:
# El nombre de mi compa es: Omar alcatraz

# %%
caramelos=int(input('cuantos caramelos hay?'))
cantidad_de_nenes=int(input('cuantos nenes hay?'))

Solucion1=caramelos//cantidad_de_nenes

sobrante=caramelos%cantidad_de_nenes

print('cada nene recibe',Solucion1)

print('sobran',sobrante,'caramelos')
# Out:
# cada nene recibe 5
# sobran 0 caramelos

# %%
def rutin():
    A_las_4am=input('que haces al levantarte')
    A_las_8am=input('que desayunas?')

    print('primera rutina:',A_las_4am)
    print('segunda rutina:',A_las_8am)

rutin()
rutin()
rutin()
# Out:
# primera rutina: me estiro
# segunda rutina: me cepillo
# primera rutina: me visto
# segunda rutina: me voy al gym
# primera rutina: me veo en el espejo
# segunda rutina: me peino

# %% [markdown]
# ESTO ES UN MARKDOWN

# %%
hamburguesa_de_usuario=input('que hamburguesa desea?')
agregados=input('desea grande o chico')

def pedidos_de_clientes(hamburguesa,extras):
    print(f'ya estamos preparando tu {hamburguesa}')
    print(f'obviamente sin olvidarnos de tus {extras}')

pedidos_de_clientes(hamburguesa_de_usuario,agregados)
# Out:
# ya estamos preparando tu microondas
# obviamente sin olvidarnos de tus 15000

# %%
def calcular_total(producto,total)
